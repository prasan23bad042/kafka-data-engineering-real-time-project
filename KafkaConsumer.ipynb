# %%
pip install s3fs
# Out:
# Requirement already satisfied: s3fs in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (2026.2.0)
# Requirement already satisfied: aiobotocore<4.0.0,>=2.19.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from s3fs) (3.2.0)
# Requirement already satisfied: fsspec==2026.2.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from s3fs) (2026.2.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from s3fs) (3.12.14)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (0.13.0)
# Requirement already satisfied: botocore<1.42.56,>=1.42.53 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.42.55)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.1.0)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (6.6.3)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.20.1)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.13.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from botocore<1.42.56,>=1.42.53->aiobotocore<4.0.0,>=2.19.0->s3fs) (2.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<4.0.0,>=2.19.0->s3fs) (1.16.0)
# Requirement already satisfied: idna>=2.0 in c:\users\saipr\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_testing2',
     bootstrap_servers=['13.53.44.221:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open('s3://kafka-real-time-stock-market-project-prasanna/stock_market_{}.json'.format(count), 'w') as file:
        json.dump(i.value, file)
    sleep(1)
